# %% [markdown]
# **Ahmad Naufal Luthfan Marzuqi - 202210370311072 - DIP B**

# %% [markdown]
# 1. memahami struktur dataset Electric_Vehicle_Population_Data.csv dengan menampilkan informasi dasar seperti tipe data, statistik deskriptif, dan 5 baris pertama.

# %%
import pandas as pd
import numpy as np
from IPython.display import display

df = pd.read_csv('Electric_Vehicle_Population_Data.csv')

print("Informasi Struktur Dataset:")
display(df.info())
print("\nStatistik Deskriptif Dataset:")
display(df.describe(include='all'))
print("\n5 Baris Pertama Dataset:")
display(df.head())

print("\nJumlah Baris dan Kolom:", df.shape)
# Out:
# Informasi Struktur Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235692 entries, 0 to 235691
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         235692 non-null  object
#  1   County                                             235689 non-null  object
#  2   City                                               235689 non-null  object
#  3   State                                              235692 non-null  object
#  4   Postal Code                                        235689 non-null  float64
#  5   Model Year                                         235692 non-null  int64
#  6   Make                                               235692 non-null  object
#  7   Model                                              235692 non-null  object
# ...

# %% [markdown]
# 2. Kode ini mengidentifikasi dan menangani masalah data seperti missing values, outliers (pada Model Year), noise (tahun < 1900), dan duplikat pada dataset kendaraan, lalu menyimpan hasilnya.

# %%
print("Jumlah Missing Values per Kolom:")
display(df.isnull().sum())

df['County'] = df['County'].fillna('Unknown')
df['City'] = df['City'].fillna('Unknown')
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].fillna('Eligibility unknown')

Q1 = df['Model Year'].quantile(0.25)
Q3 = df['Model Year'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['Model Year'] < lower_bound) | (df['Model Year'] > upper_bound)]
print("\nJumlah Outliers di Model Year:", len(outliers))
print("Contoh Outliers di Model Year:")
print(outliers[['Model Year']].head())

df = df[(df['Model Year'] >= lower_bound) & (df['Model Year'] <= upper_bound)]

noise = df[df['Model Year'] < 1900]
print("\nJumlah Noise di Model Year (< 1900):", len(noise))
df = df[df['Model Year'] >= 1900]

print("\nJumlah Duplikat:", df.duplicated().sum())
df = df.drop_duplicates()

df.to_csv('Cleaned_Electric_Vehicle_Population_Data.csv', index=False)
print("\nDataset setelah pembersihan disimpan.")
# Out:
# Jumlah Missing Values per Kolom:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        36
# Base MSRP                                             36
# Legislative District                                 484
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       3
# ...

# %% [markdown]
# 3. Kode ini membersihkan inkonsistensi nama di kolom Make dan CompanyName dengan menghapus karakter khusus (termasuk underscore) dan spasi, lalu menstandarisasi ke huruf kapital.

# %%
import pandas as pd
import re

df_vehicle = pd.read_csv('Electric_Vehicle_Population_Data.csv')

df_company = pd.read_csv('company_esg_financial_dataset.csv')

print("Nilai Unik di 'Make' (Dataset Kendaraan) Sebelum Pembersihan:")
print(df_vehicle['Make'].unique()[:10])
print("\nNilai Unik di 'CompanyName' (Dataset Perusahaan) Sebelum Pembersihan:")
print(df_company['CompanyName'].unique()[:10])

def clean_name(name):
    if pd.isna(name):  # Tangani nilai NaN
        return name
    cleaned = re.sub(r'[^a-zA-Z0-9]', '', str(name))
    return cleaned.strip().upper()

df_vehicle['Make_Cleaned'] = df_vehicle['Make'].apply(clean_name)
df_company['CompanyName_Cleaned'] = df_company['CompanyName'].apply(clean_name)

print("\nNilai Unik di 'Make_Cleaned' (Dataset Kendaraan) Setelah Pembersihan:")
print(df_vehicle['Make_Cleaned'].unique()[:10])
print("\nNilai Unik di 'CompanyName_Cleaned' (Dataset Perusahaan) Setelah Pembersihan:")
print(df_company['CompanyName_Cleaned'].unique()[:10])
# Out:
# Nilai Unik di 'Make' (Dataset Kendaraan) Sebelum Pembersihan:
# ['TESLA' 'HYUNDAI' 'BMW' 'TOYOTA' 'NISSAN' 'KIA' 'POLESTAR' 'MAZDA'
#  'CHEVROLET' 'VOLVO']
#
# Nilai Unik di 'CompanyName' (Dataset Perusahaan) Sebelum Pembersihan:
# ['Company_1' 'Company_2' 'Company_3' 'Company_4' 'Company_5' 'Company_6'
#  'Company_7' 'Company_8' 'Company_9' 'Company_10']
#
# Nilai Unik di 'Make_Cleaned' (Dataset Kendaraan) Setelah Pembersihan:
# ['TESLA' 'HYUNDAI' 'BMW' 'TOYOTA' 'NISSAN' 'KIA' 'POLESTAR' 'MAZDA'
#  'CHEVROLET' 'VOLVO']
#
# Nilai Unik di 'CompanyName_Cleaned' (Dataset Perusahaan) Setelah Pembersihan:
# ['COMPANY1' 'COMPANY2' 'COMPANY3' 'COMPANY4' 'COMPANY5' 'COMPANY6'
#  'COMPANY7' 'COMPANY8' 'COMPANY9' 'COMPANY10']
